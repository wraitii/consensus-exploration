# %%
import pandas as pd
import os

# %%
files = [f for f in os.listdir('../') if f.endswith('.csv')]
files
# Out:
# ['output-1718377901860.csv',
#  'output-2024.csv',
#  'output-1718377858535.csv',
#  'output-1718377857203.csv',
#  'output-1718377665343.csv',
#  'output-1718377896974.csv',
#  'output-1718377870189.csv',
#  'output-1718377855722.csv',
#  'output-1718377871351.csv',
#  'output-1718377757558.csv']

# %%
df = pd.read_csv(f'../{files[0]}')

# %%
df
# Out:
#       Time  Level  Peers  Byzantine  Signals
# 0        1      1     40          4       40
# 1        2      1     40          4       40
# 2        3      1     40          4       39
# 3        4      1     40          4       37
# 4        5      1     40          4       35
# ...    ...    ...    ...        ...      ...
# 2995  2996    125     40          4       75
# 2996  2997    125     40          4       62
# 2997  2998    125     40          4       44
# 2998  2999    125     40          4       41
# 2999  3000    125     40          4       25
#
# [3000 rows x 5 columns]

# %%
import seaborn as sn

# %%
sn.lineplot(df, x='Time', y='Signals')
# Out:
# <Axes: xlabel='Time', ylabel='Signals'>
